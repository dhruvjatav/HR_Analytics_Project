# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/HR_Analytics_Data.csv")
df.head()
# Out:
#    EmployeeID        Name  Age  Gender  Department    JobRole    Education  \
# 0        1001  Employee_1   50    Male       Sales  Executive  High School
# 1        1002  Employee_2   36  Female       Sales    Manager       Master
# 2        1003  Employee_3   29    Male          IT    Analyst          PhD
# 3        1004  Employee_4   42  Female          IT  Scientist          PhD
# 4        1005  Employee_5   40  Female  Operations    Manager       Master
#
#   EducationField MaritalStatus  MonthlyIncome  ...  YearsAtCompany  \
# 0        Medical        Single          18754  ...              15
# 1    Engineering      Divorced          42044  ...              16
# 2        Medical        Single          82260  ...              14
# 3           Arts        Single          81912  ...               2
# 4       Business      Divorced          23706  ...              11
#
#    YearsInCurrentRole  YearsSinceLastPromotion YearsWithCurrManager  \
# 0                  10                        5                    6
# 1                  10                        1                    8
# 2                   2                        2                    9
# 3                  11                        6                    4
# 4                   2                        1                    0
#
#    JobSatisfaction  WorkLifeBalance  EnvironmentSatisfaction  \
# 0                1                1                        2
# 1                4                1                        2
# 2                3                3                        1
# 3                3                3                        3
# 4                4                4                        4
#
#       BusinessTravel  DistanceFromHome  Attrition
# 0         Non-Travel                10         No
# 1      Travel_Rarely                25         No
# 2  Travel_Frequently                34         No
# 3  Travel_Frequently                37        Yes
# 4         Non-Travel                30         No
#
# [5 rows x 25 columns]

# %%
df.isnull().sum()
# Out:
# EmployeeID                 0
# Name                       0
# Age                        0
# Gender                     0
# Department                 0
# JobRole                    0
# Education                  0
# EducationField             0
# MaritalStatus              0
# MonthlyIncome              0
# HourlyRate                 0
# DailyRate                  0
# MonthlyRate                0
# OverTime                   0
# TotalWorkingYears          0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# JobSatisfaction            0
# WorkLifeBalance            0
# EnvironmentSatisfaction    0
# BusinessTravel             0
# DistanceFromHome           0
# Attrition                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               400 non-null    int64
#  1   Name                     400 non-null    object
#  2   Age                      400 non-null    int64
#  3   Gender                   400 non-null    object
#  4   Department               400 non-null    object
#  5   JobRole                  400 non-null    object
#  6   Education                400 non-null    object
#  7   EducationField           400 non-null    object
#  8   MaritalStatus            400 non-null    object
#  9   MonthlyIncome            400 non-null    int64
#  10  HourlyRate               400 non-null    int64
#  11  DailyRate                400 non-null    int64
#  12  MonthlyRate              400 non-null    int64
#  13  OverTime                 400 non-null    object
#  14  TotalWorkingYears        400 non-null    int64
#  15  YearsAtCompany           400 non-null    int64
#  16  YearsInCurrentRole       400 non-null    int64
#  17  YearsSinceLastPromotion  400 non-null    int64
#  18  YearsWithCurrManager     400 non-null    int64
#  19  JobSatisfaction          400 non-null    int64
#  20  WorkLifeBalance          400 non-null    int64
#  21  EnvironmentSatisfaction  400 non-null    int64
#  22  BusinessTravel           400 non-null    object
#  23  DistanceFromHome         400 non-null    int64
#  24  Attrition                400 non-null    object
# dtypes: int64(15), object(10)
# memory usage: 78.3+ KB

# %%
sns.countplot(x="Attrition", data=df)
plt.title("Attrition Distribution")
plt.show()

# %%
sns.countplot(x="Gender", data=df)
plt.title("Gender Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="Department", data=df)
plt.title("Employees by Department")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["MonthlyIncome"], bins=30, kde=True)
plt.title("Monthly Income Distribution")
plt.show()
